# %%
pwd()
# Out:
# 'C:\\Users\\Vipul Ahuja\\inueron\\pythoncore'

# %%
import pymongo

# %%
dbcon=pymongo.MongoClient('mongodb://localhost:27017/')

# %%
dbname= 'admin'

# %%
print(dbcon[dbname])
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'admin')

# %%
conn = dbcon[db]

# %%
db = 'demodatabase'

# %%
print(dbcon[db])
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'demodatabase')

# %%
dbcon.get_database(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'demodatabase')

# %%
dbcon.list_database_names()
# Out:
# ['admin', 'config', 'demodatabase', 'local']

# %%
db['telemarketing']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-04212d3ca5ae> in <module>
# ----> 1 db['telemarketing']
#
# TypeError: string indices must be integers

# %%
collection= dbcon[db].list_collection_names()

# %%
collection.insert_one(myrow)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-436297f6bc6b> in <module>
# ----> 1 collection.insert_one(myrow)
#
# AttributeError: 'list' object has no attribute 'insert_one'

# %%
myrow=  {"RowNumber": "10002",
    "CustomerId": "15634602",
    "Surname": "Hargrave",
    "CreditScore": "619",
    "Geography": "France",
    "Gender": "Female",
    "Age": "42",
    "Tenure": "2",
    "Balance": "0",
    "NumOfProducts": "1",
    "HasCrCard": "1",
    "IsActiveMember": "1",
    "EstimatedSalary": "101348.88",
    "Exited": "1"}

# %%
x=conn['telemarketing'].insert_one(myrow)

# %%
x.inserted_id
# Out:
# ObjectId('6155eb8d673f833a73953de5')

# %%
myrownew= [ {"RowNumber": "10002",
    "CustomerId": "15634602",
    "Surname": "Hargrave",
    "CreditScore": "619",
    "Geography": "France",
    "Gender": "Female",
    "Age": "42",
    "Tenure": "2",
    "Balance": "0",
    "NumOfProducts": "1",
    "HasCrCard": "1",
    "IsActiveMember": "1",
    "EstimatedSalary": "101348.88",
    "Exited": "1"},{"RowNumber": "10003",
    "CustomerId": "15634602",
    "Surname": "Hargrave",
    "CreditScore": "619",
    "Geography": "France",
    "Gender": "Female",
    "Age": "42",
    "Tenure": "2",
    "Balance": "0",
    "NumOfProducts": "1",
    "HasCrCard": "1",
    "IsActiveMember": "1",
    "EstimatedSalary": "101348.88",
    "Exited": "1"},
          {"RowNumber": "10004",
    "CustomerId": "15634602",
    "Surname": "Hargrave",
    "CreditScore": "619",
    "Geography": "France",
    "Gender": "Female",
    "Age": "42",
    "Tenure": "2",
    "Balance": "0",
    "NumOfProducts": "1",
    "HasCrCard": "1",
    "IsActiveMember": "1",
    "EstimatedSalary": "101348.88",
    "Exited": "1"}]

# %%
y=conn['telemarketing'].insert_many(myrownew)

# %%
y.inserted_ids
# Out:
# [ObjectId('6155ec1a673f833a73953de6'),
#  ObjectId('6155ec1a673f833a73953de7'),
#  ObjectId('6155ec1a673f833a73953de8')]

# %%
conn['telemarketing'].count()
# Out:
# <ipython-input-32-3a1d00027ff0>:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   conn['telemarketing'].count()
# 10005

# %%
conn['telemarketing'].distinct('Geography')
# Out:
# ['France', 'Germany', 'Spain']

# %%
newa= conn['telemarketing'].delete_one({})

# %%
#select * from condition is like in mongo db
res= conn['telemarketing'].find({})

# %%
res[4]
# Out:
# {'_id': ObjectId('6155e69e868b7aaa257ad598'),
#  'RowNumber': '5',
#  'CustomerId': '15737888',
#  'Surname': 'Mitchell',
#  'CreditScore': '850',
#  'Geography': 'Spain',
#  'Gender': 'Female',
#  'Age': '43',
#  'Tenure': '2',
#  'Balance': '125510.82',
#  'NumOfProducts': '1',
#  'HasCrCard': '1',
#  'IsActiveMember': '1',
#  'EstimatedSalary': '79084.1',
#  'Exited': '0'}

# %%
newa.deleted_count
# Out:
# 1

# %%
#we can also set the limit 
res1 =  conn['telemarketing'].find({}).limit(10)

# %%
for r in res1:
    print(r)
# Out:
# {'_id': ObjectId('6155e69e868b7aaa257ad598'), 'RowNumber': '5', 'CustomerId': '15737888', 'Surname': 'Mitchell', 'CreditScore': '850', 'Geography': 'Spain', 'Gender': 'Female', 'Age': '43', 'Tenure': '2', 'Balance': '125510.82', 'NumOfProducts': '1', 'HasCrCard': '1', 'IsActiveMember': '1', 'EstimatedSalary': '79084.1', 'Exited': '0'}
# {'_id': ObjectId('6155e69e868b7aaa257ad599'), 'RowNumber': '6', 'CustomerId': '15574012', 'Surname': 'Chu', 'CreditScore': '645', 'Geography': 'Spain', 'Gender': 'Male', 'Age': '44', 'Tenure': '8', 'Balance': '113755.78', 'NumOfProducts': '2', 'HasCrCard': '1', 'IsActiveMember': '0', 'EstimatedSalary': '149756.71', 'Exited': '1'}
# ...

# %%
res= conn['telemarketing'].find({}).explain()

# %%
for d in res:
    print(d)
# Out:
# queryPlanner
# executionStats
# serverInfo
# ok

# %%
rest= conn['telemarketing'].find({}).max(['id'])

# %%
rest

# %%
for t in rest:
    print(t)
# Out:
# <ipython-input-58-f01e5cdfec01>:1: DeprecationWarning: using a min/max query operator without specifying a Cursor.hint is deprecated. A hint will be required when using min/max in PyMongo 4.0
#   for t in rest:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-58-f01e5cdfec01> in <module>
# ----> 1 for t in rest:
#       2     print(t)
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1236         if self.__empty:
#    1237             raise StopIteration
# -> 1238         if len(self.__data) or self._refresh():
#    1239             if self.__manipulate:
#    1240                 _db = self.__collection.database
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1153                                   self.__allow_disk_use,
#    1154                                   self.__exhaust)
# ...

# %%
#finding 2 colmnns
res= conn['telemarketing'].find({},{'RowNumber','CustomerId'})

# %%
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6155e69e868b7aaa257ad598'), 'RowNumber': '5', 'CustomerId': '15737888'}
# {'_id': ObjectId('6155e69e868b7aaa257ad599'), 'RowNumber': '6', 'CustomerId': '15574012'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59a'), 'RowNumber': '7', 'CustomerId': '15592531'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59b'), 'RowNumber': '8', 'CustomerId': '15656148'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59c'), 'RowNumber': '9', 'CustomerId': '15792365'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59d'), 'RowNumber': '10', 'CustomerId': '15592389'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59e'), 'RowNumber': '11', 'CustomerId': '15767821'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59f'), 'RowNumber': '12', 'CustomerId': '15737173'}
# {'_id': ObjectId('6155e69e868b7aaa257ad5a0'), 'RowNumber': '13', 'CustomerId': '15632264'}
# {'_id': ObjectId('6155e69e868b7aaa257ad5a1'), 'RowNumber': '14', 'CustomerId': '15691483'}
# ...

# %%
#sort in ascending order 
res= conn['telemarketing'].find({},{'RowNumber','CustomerId'}).limit(5).sort('CustomerId')

# %%
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6155e69e868b7aaa257ad598'), 'RowNumber': '5', 'CustomerId': '15737888'}
# {'_id': ObjectId('6155e69e868b7aaa257ad599'), 'RowNumber': '6', 'CustomerId': '15574012'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59a'), 'RowNumber': '7', 'CustomerId': '15592531'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59b'), 'RowNumber': '8', 'CustomerId': '15656148'}
# {'_id': ObjectId('6155e69e868b7aaa257ad59c'), 'RowNumber': '9', 'CustomerId': '15792365'}

# %%
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6155e69e868b7aaa257ada9b'), 'RowNumber': '1288', 'CustomerId': '15565701'}
# {'_id': ObjectId('6155e69e868b7aaa257ae5fa'), 'RowNumber': '4199', 'CustomerId': '15565706'}
# {'_id': ObjectId('6155e69e868b7aaa257af146'), 'RowNumber': '7091', 'CustomerId': '15565714'}
# {'_id': ObjectId('6155e69e868b7aaa257add78'), 'RowNumber': '2021', 'CustomerId': '15565779'}
# {'_id': ObjectId('6155e69e868b7aaa257ae405'), 'RowNumber': '3698', 'CustomerId': '15565796'}

# %%
#if we want to sort in descending order in that case
res= conn['telemarketing'].find({},{'RowNumber','CustomerId'}).limit(5).sort('CustomerId',-1)

# %%
for i in res:
    print(i)
# Out:
# {'_id': ObjectId('6155e69e868b7aaa257aeb12'), 'RowNumber': '5503', 'CustomerId': '15815690'}
# {'_id': ObjectId('6155e69e868b7aaa257adc76'), 'RowNumber': '1763', 'CustomerId': '15815660'}
# {'_id': ObjectId('6155e69f868b7aaa257af52c'), 'RowNumber': '8089', 'CustomerId': '15815656'}
# {'_id': ObjectId('6155e69f868b7aaa257af5e3'), 'RowNumber': '8272', 'CustomerId': '15815645'}
# {'_id': ObjectId('6155e69e868b7aaa257ae2e7'), 'RowNumber': '3412', 'CustomerId': '15815628'}

# %%
my_query = {'RowNumber':'10005'}
conn['telemarketing'].delete_one(my_query)

# %%
conn['telemarketing'].find(my_query)

# %%
#update command
update_values = {'Surname':'Mitchell'}
new_value = {"$set":{'Surname':'Mitch'}}

# %%
conn['telemarketing'].update_many(update_values,new_value)
